# %% [markdown]
# <a href="https://colab.research.google.com/github/divyasankritya/ISL/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Import necessary libraries
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, TimeDistributed, LSTM, Dense, GlobalAveragePooling2D, Dropout, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
import zipfile
import os

zip_path = '/content/drive/MyDrive/dataset.zip'  # Replace with your actual path
extract_to = '/content/drive/MyDrive/dataset'    # Folder where you want to extract

with zipfile.ZipFile('/content/drive/MyDrive/DATASET/archive.zip', 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print("Extraction completed!")
# Out:
# Extraction completed!

# %%
IMG_HEIGHT, IMG_WIDTH = 224, 224       # Size expected by MobileNetV2
NUM_FRAMES = 10                        # Fixed number of frames per sample (pad or truncate)
BATCH_SIZE = 16
INITIAL_EPOCHS = 50                    # First phase training epochs with frozen CNN
FINETUNE_EPOCHS = 50                   # Additional epochs after unfreezing part of the CNN
TOTAL_EPOCHS = INITIAL_EPOCHS + FINETUNE_EPOCHS
DATASET_DIR = '/content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level'  # Change this path to your dataset path

# %%
def load_frame(image_path):
    """
    Loads an image from disk, resizes it, and applies MobileNetV2 preprocessing.
    """
    img = cv2.imread(image_path)
    if img is None:
        raise ValueError(f"Error reading image: {image_path}")
    # Convert from BGR (OpenCV default) to RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_WIDTH, IMG_HEIGHT))
    img = preprocess_input(img)  # This scales pixels as required by MobileNetV2
    return img

def load_dataset(dataset_dir):
    """
    Loads the dataset from the specified directory.

    Expected structure:
    dataset_dir/
         Word1/
             image1.jpg
             image2.jpg
             ... (possibly many images representing multiple samples)
         Word2/
             image1.jpg
             image2.jpg
         ...

    The function groups images into sequences of NUM_FRAMES. If there are more images,
    they are split into consecutive chunks. If there are fewer than NUM_FRAMES, the chunk is padded.

    Returns:
      X: numpy array of shape (num_samples, NUM_FRAMES, IMG_HEIGHT, IMG_WIDTH, 3)
      y: numpy array of integer labels for each sample
      label_map: dictionary mapping word names to integer indices
    """
    X, y = [], []
    label_map = {}
    current_label = 0

    # Loop through each word folder (each word is a label)
    for word in sorted(os.listdir(dataset_dir)):
        word_folder = os.path.join(dataset_dir, word)
        if os.path.isdir(word_folder):
            print(f"\nProcessing label: {word}")
            label_map[word] = current_label

            # List image files directly in the word folder (ignore subfolders)
            image_files = sorted([os.path.join(word_folder, f)
                                  for f in os.listdir(word_folder)
                                  if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
            if not image_files:
                print(f"  No image files found in {word_folder}.")
                continue

            num_images = len(image_files)
            # Group the images into consecutive sequences of NUM_FRAMES
            for i in range(0, num_images, NUM_FRAMES):
                sequence_files = image_files[i:i+NUM_FRAMES]
                frames = [load_frame(fp) for fp in sequence_files]
                # If the chunk has fewer than NUM_FRAMES, pad with zeros
                if len(frames) < NUM_FRAMES:
                    pad_count = NUM_FRAMES - len(frames)
                    pad_frame = np.zeros((IMG_HEIGHT, IMG_WIDTH, 3), dtype=np.float32)
                    frames.extend([pad_frame] * pad_count)
                X.append(np.array(frames))
                y.append(current_label)
                print(f"  Loaded sample from {word_folder}: images {i+1} to {i+len(sequence_files)}")
            current_label += 1

    return np.array(X), np.array(y), label_map

# %%
print("Loading dataset from Frames_words_level...")
X, y, label_map = load_dataset(DATASET_DIR)
print(f"\nDataset loaded: {X.shape[0]} samples, {len(label_map)} classes.")
print("Label map:", label_map)

if X.shape[0] < 2:
    raise ValueError("Not enough samples loaded. Check the dataset path and structure.")

# Convert labels to one-hot encoding
num_classes = len(label_map)
y_cat = to_categorical(y, num_classes=num_classes)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_cat, test_size=0.2, random_state=42)
print(f"Train samples: {X_train.shape[0]}, Test samples: {X_test.shape[0]}")
# Out:
# Loading dataset from Frames_words_level...
#
# Processing label: A LOT
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/A LOT: images 1 to 4
#
# Processing label: ABUSE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/ABUSE: images 1 to 5
#
# Processing label: AFRAID
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/AFRAID: images 1 to 6
#
# Processing label: AGREE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/AGREE: images 1 to 7
#
# Processing label: ALL
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/ALL: images 1 to 4
#
# Processing label: ANGRY
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/ANGRY: images 1 to 10
#
# Processing label: ANYTHING
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/ANYTHING: images 1 to 4
#
# Processing label: APPRECIATE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/APPRECIATE: images 1 to 5
#
# Processing label: BAD
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/BAD: images 1 to 5
#
# Processing label: BEAUTIFUL
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/BEAUTIFUL: images 1 to 5
#
# Processing label: BECOME
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/BECOME: images 1 to 5
#
# Processing label: BED
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/BED: images 1 to 7
#
# Processing label: BORED
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/BORED: images 1 to 6
#
# Processing label: BRING
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/BRING: images 1 to 7
#
# Processing label: CHAT
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/CHAT: images 1 to 6
#
# Processing label: CLASS
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/CLASS: images 1 to 5
#
# Processing label: COLD
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/COLD: images 1 to 7
#
# Processing label: COLLEGE_SCHOOL
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/COLLEGE_SCHOOL: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/COLLEGE_SCHOOL: images 11 to 18
#
# Processing label: COMB
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/COMB: images 1 to 7
#
# Processing label: COME
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/COME: images 1 to 6
#
# Processing label: CONGRATULATIONS
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/CONGRATULATIONS: images 1 to 7
#
# Processing label: CRYING
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/CRYING: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/CRYING: images 11 to 13
#
# Processing label: DARE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/DARE: images 1 to 6
#
# Processing label: DIFFERENCE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/DIFFERENCE: images 1 to 5
#
# Processing label: DILEMMA
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/DILEMMA: images 1 to 6
#
# Processing label: DISAPPOINTED
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/DISAPPOINTED: images 1 to 6
#
# Processing label: DO
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/DO: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/DO: images 11 to 12
#
# Processing label: DON'T CARE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/DON'T CARE: images 1 to 3
#
# Processing label: ENJOY
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/ENJOY: images 1 to 4
#
# Processing label: FAVOUR
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/FAVOUR: images 1 to 4
#
# Processing label: FEVER
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/FEVER: images 1 to 7
#
# Processing label: FINE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/FINE: images 1 to 6
#
# Processing label: FOOD
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/FOOD: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/FOOD: images 11 to 20
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/FOOD: images 21 to 23
#
# Processing label: FREE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/FREE: images 1 to 7
#
# Processing label: FRIEND
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/FRIEND: images 1 to 6
#
# Processing label: FROM
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/FROM: images 1 to 7
#
# Processing label: GO
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/GO: images 1 to 9
#
# Processing label: GOOD
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/GOOD: images 1 to 7
#
# Processing label: GRATEFUL
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/GRATEFUL: images 1 to 6
#
# Processing label: HAD
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HAD: images 1 to 4
#
# Processing label: HAPPENED
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HAPPENED: images 1 to 5
#
# Processing label: HAPPY
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HAPPY: images 1 to 5
#
# Processing label: HEAR
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HEAR: images 1 to 7
#
# Processing label: HEART
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HEART: images 1 to 6
#
# Processing label: HELLO_HI
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HELLO_HI: images 1 to 4
#
# Processing label: HELP
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HELP: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HELP: images 11 to 20
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HELP: images 21 to 26
#
# Processing label: HIDING
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HIDING: images 1 to 6
#
# Processing label: HOW
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HOW: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HOW: images 11 to 20
#
# Processing label: HUNGRY
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HUNGRY: images 1 to 7
#
# Processing label: HURT
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HURT: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/HURT: images 11 to 14
#
# Processing label: I_ME_MINE_MY
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/I_ME_MINE_MY: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/I_ME_MINE_MY: images 11 to 20
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/I_ME_MINE_MY: images 21 to 30
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/I_ME_MINE_MY: images 31 to 40
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/I_ME_MINE_MY: images 41 to 50
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/I_ME_MINE_MY: images 51 to 60
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/I_ME_MINE_MY: images 61 to 70
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/I_ME_MINE_MY: images 71 to 80
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/I_ME_MINE_MY: images 81 to 90
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/I_ME_MINE_MY: images 91 to 97
#
# Processing label: KIND
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/KIND: images 1 to 7
#
# Processing label: LEAVE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/LEAVE: images 1 to 5
#
# Processing label: LIKE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/LIKE: images 1 to 6
#
# Processing label: LIKE_LOVE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/LIKE_LOVE: images 1 to 7
#
# Processing label: MEAN IT
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/MEAN IT: images 1 to 3
#
# Processing label: MEDICINE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/MEDICINE: images 1 to 6
#
# Processing label: MEET
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/MEET: images 1 to 5
#
# Processing label: NAME
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/NAME: images 1 to 7
#
# Processing label: NICE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/NICE: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/NICE: images 11 to 15
#
# Processing label: NOT
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/NOT: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/NOT: images 11 to 16
#
# Processing label: NUMBER
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/NUMBER: images 1 to 8
#
# Processing label: OLD_AGE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/OLD_AGE: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/OLD_AGE: images 11 to 12
#
# Processing label: ON THE WAY
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/ON THE WAY: images 1 to 3
#
# Processing label: OUTSIDE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/OUTSIDE: images 1 to 6
#
# Processing label: PHONE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/PHONE: images 1 to 7
#
# Processing label: PLACE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/PLACE: images 1 to 4
#
# Processing label: PLEASE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/PLEASE: images 1 to 2
#
# Processing label: POUR
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/POUR: images 1 to 7
#
# Processing label: PREPARE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/PREPARE: images 1 to 6
#
# Processing label: PROMISE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/PROMISE: images 1 to 7
#
# Processing label: REALLY
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/REALLY: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/REALLY: images 11 to 12
#
# Processing label: REPEAT
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/REPEAT: images 1 to 6
#
# Processing label: ROOM
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/ROOM: images 1 to 8
#
# Processing label: SERVE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SERVE: images 1 to 7
#
# Processing label: SHIRT
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SHIRT: images 1 to 7
#
# Processing label: SITTING
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SITTING: images 1 to 5
#
# Processing label: SLEEP
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SLEEP: images 1 to 5
#
# Processing label: SLOWER
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SLOWER: images 1 to 5
#
# Processing label: SO MUCH
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SO MUCH: images 1 to 7
#
# Processing label: SOFTLY
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SOFTLY: images 1 to 5
#
# Processing label: SOME HOW
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SOME HOW: images 1 to 7
#
# Processing label: SOME ONE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SOME ONE: images 1 to 10
#
# Processing label: SOMETHING
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SOMETHING: images 1 to 3
#
# Processing label: SORRY
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SORRY: images 1 to 6
#
# Processing label: SPEAK
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SPEAK: images 1 to 5
#
# Processing label: STOP
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/STOP: images 1 to 6
#
# Processing label: STUBBORN
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/STUBBORN: images 1 to 5
#
# Processing label: SURE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/SURE: images 1 to 6
#
# Processing label: TAKE CARE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/TAKE CARE: images 1 to 8
#
# Processing label: TAKE TIME
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/TAKE TIME: images 1 to 7
#
# Processing label: TALK
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/TALK: images 1 to 7
#
# Processing label: TELL
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/TELL: images 1 to 9
#
# Processing label: THANK
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/THANK: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/THANK: images 11 to 14
#
# Processing label: THAT
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/THAT: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/THAT: images 11 to 12
#
# Processing label: THINGS
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/THINGS: images 1 to 3
#
# Processing label: THINK
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/THINK: images 1 to 7
#
# Processing label: THIRSTY
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/THIRSTY: images 1 to 7
#
# Processing label: TIRED
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/TIRED: images 1 to 6
#
# Processing label: TODAY
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/TODAY: images 1 to 7
#
# Processing label: TRAIN
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/TRAIN: images 1 to 5
#
# Processing label: TRUST
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/TRUST: images 1 to 4
#
# Processing label: TRUTH
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/TRUTH: images 1 to 4
#
# Processing label: TURN ON
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/TURN ON: images 1 to 6
#
# Processing label: UNDERSTAND
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/UNDERSTAND: images 1 to 5
#
# Processing label: WANT
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WANT: images 1 to 5
#
# Processing label: WATER
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WATER: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WATER: images 11 to 20
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WATER: images 21 to 21
#
# Processing label: WEAR
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WEAR: images 1 to 7
#
# Processing label: WELCOME
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WELCOME: images 1 to 5
#
# Processing label: WHAT
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WHAT: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WHAT: images 11 to 20
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WHAT: images 21 to 30
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WHAT: images 31 to 31
#
# Processing label: WHERE
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WHERE: images 1 to 7
#
# Processing label: WHO
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WHO: images 1 to 7
#
# Processing label: WORRY
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/WORRY: images 1 to 4
#
# Processing label: YOU
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/YOU: images 1 to 10
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/YOU: images 11 to 20
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/YOU: images 21 to 30
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/YOU: images 31 to 40
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/YOU: images 41 to 50
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/YOU: images 51 to 60
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/YOU: images 61 to 70
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/YOU: images 71 to 80
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/YOU: images 81 to 90
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/YOU: images 91 to 100
#   Loaded sample from /content/drive/MyDrive/dataset/ISL_CSLRT_Corpus/ISL_CSLRT_Corpus/Frames_Word_Level/YOU: images 101 to 110
#
# Dataset loaded: 153 samples, 114 classes.
# Label map: {'A LOT': 0, 'ABUSE': 1, 'AFRAID': 2, 'AGREE': 3, 'ALL': 4, 'ANGRY': 5, 'ANYTHING': 6, 'APPRECIATE': 7, 'BAD': 8, 'BEAUTIFUL': 9, 'BECOME': 10, 'BED': 11, 'BORED': 12, 'BRING': 13, 'CHAT': 14, 'CLASS': 15, 'COLD': 16, 'COLLEGE_SCHOOL': 17, 'COMB': 18, 'COME': 19, 'CONGRATULATIONS': 20, 'CRYING': 21, 'DARE': 22, 'DIFFERENCE': 23, 'DILEMMA': 24, 'DISAPPOINTED': 25, 'DO': 26, "DON'T CARE": 27, 'ENJOY': 28, 'FAVOUR': 29, 'FEVER': 30, 'FINE': 31, 'FOOD': 32, 'FREE': 33, 'FRIEND': 34, 'FROM': 35, 'GO': 36, 'GOOD': 37, 'GRATEFUL': 38, 'HAD': 39, 'HAPPENED': 40, 'HAPPY': 41, 'HEAR': 42, 'HEART': 43, 'HELLO_HI': 44, 'HELP': 45, 'HIDING': 46, 'HOW': 47, 'HUNGRY': 48, 'HURT': 49, 'I_ME_MINE_MY': 50, 'KIND': 51, 'LEAVE': 52, 'LIKE': 53, 'LIKE_LOVE': 54, 'MEAN IT': 55, 'MEDICINE': 56, 'MEET': 57, 'NAME': 58, 'NICE': 59, 'NOT': 60, 'NUMBER': 61, 'OLD_AGE': 62, 'ON THE WAY': 63, 'OUTSIDE': 64, 'PHONE': 65, 'PLACE': 66, 'PLEASE': 67, 'POUR': 68, 'PREPARE': 69, 'PROMISE': 70, 'REALLY': 71, 'REPEAT': 72, 'ROOM': 73, 'SERVE': 74, 'SHIRT': 75, 'SITTING': 76, 'SLEEP': 77, 'SLOWER': 78, 'SO MUCH': 79, 'SOFTLY': 80, 'SOME HOW': 81, 'SOME ONE': 82, 'SOMETHING': 83, 'SORRY': 84, 'SPEAK': 85, 'STOP': 86, 'STUBBORN': 87, 'SURE': 88, 'TAKE CARE': 89, 'TAKE TIME': 90, 'TALK': 91, 'TELL': 92, 'THANK': 93, 'THAT': 94, 'THINGS': 95, 'THINK': 96, 'THIRSTY': 97, 'TIRED': 98, 'TODAY': 99, 'TRAIN': 100, 'TRUST': 101, 'TRUTH': 102, 'TURN ON': 103, 'UNDERSTAND': 104, 'WANT': 105, 'WATER': 106, 'WEAR': 107, 'WELCOME': 108, 'WHAT': 109, 'WHERE': 110, 'WHO': 111, 'WORRY': 112, 'YOU': 113}
# Train samples: 122, Test samples: 31

# %%
input_shape = (NUM_FRAMES, IMG_HEIGHT, IMG_WIDTH, 3)
sequence_input = Input(shape=input_shape)

# Create the CNN base using MobileNetV2
cnn_base = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))
cnn_output = GlobalAveragePooling2D()(cnn_base.output)
cnn_model = Model(inputs=cnn_base.input, outputs=cnn_output)
cnn_model.trainable = False  # Initially freeze the CNN base

# Apply the CNN to each frame using TimeDistributed
encoded_frames = TimeDistributed(cnn_model)(sequence_input)

# Use a Bidirectional LSTM for better temporal feature learning
bi_lstm = Bidirectional(LSTM(64, return_sequences=False))(encoded_frames)
dropout = Dropout(0.5)(bi_lstm)
output = Dense(num_classes, activation='softmax')(dropout)

model = Model(inputs=sequence_input, outputs=output)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 10, 224, 224,   │             0 │
# │                                 │ 3)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 10, 1280)       │     2,257,984 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 128)            │       688,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 114)            │        14,706 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,961,330 (11.30 MB)
#  Trainable params: 703,346 (2.68 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
print("\nStarting initial training with frozen CNN base...")
history1 = model.fit(X_train, y_train,
                     validation_data=(X_test, y_test),
                     epochs=INITIAL_EPOCHS,
                     batch_size=BATCH_SIZE)
# Out:
# Starting initial training with frozen CNN base...
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 128s 9s/step - accuracy: 0.0321 - loss: 4.8156 - val_accuracy: 0.0000e+00 - val_loss: 4.8541
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 73s 8s/step - accuracy: 0.0675 - loss: 4.5970 - val_accuracy: 0.0000e+00 - val_loss: 4.9020
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.1042 - loss: 4.3599 - val_accuracy: 0.0000e+00 - val_loss: 4.9197
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 84s 8s/step - accuracy: 0.1625 - loss: 4.0188 - val_accuracy: 0.0000e+00 - val_loss: 4.9609
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 81s 8s/step - accuracy: 0.1465 - loss: 4.0132 - val_accuracy: 0.0000e+00 - val_loss: 5.0267
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 82s 8s/step - accuracy: 0.1511 - loss: 4.0083 - val_accuracy: 0.0645 - val_loss: 5.0975
# Epoch 7/50
# 4/8 ━━━━━━━━━━━━━━━━━━━━ 21s 5s/step - accuracy: 0.2018 - loss: 3.6099

# %%
print("\nUnfreezing the last few layers of MobileNetV2 for fine-tuning...")
# Unfreeze the last 20 layers of MobileNetV2
for layer in cnn_base.layers[-20:]:
    layer.trainable = True

# Compile the model with a lower learning rate for fine-tuning
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()

print("\nStarting fine-tuning training...")
history2 = model.fit(X_train, y_train,
                     validation_data=(X_test, y_test),
                     epochs=FINETUNE_EPOCHS,
                     batch_size=BATCH_SIZE)
# Out:
# Unfreezing the last few layers of MobileNetV2 for fine-tuning...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a80dc578cf81> in <cell line: 0>()
#       1 print("\nUnfreezing the last few layers of MobileNetV2 for fine-tuning...")
#       2 # Unfreeze the last 20 layers of MobileNetV2
# ----> 3 for layer in cnn_base.layers[-20:]:
#       4     layer.trainable = True
#       5
#
# NameError: name 'cnn_base' is not defined

# %%
loss, accuracy = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")

# %%
idx = 0  # choose a sample index from the test set
sample = X_test[idx]  # shape: (NUM_FRAMES, IMG_HEIGHT, IMG_WIDTH, 3)
true_label = np.argmax(y_test[idx])
pred_probs = model.predict(np.expand_dims(sample, axis=0))
pred_label = np.argmax(pred_probs)

print(f"\nTrue label index: {true_label}, Predicted label index: {pred_label}")
print("Corresponding word labels:")
for word, idx_val in label_map.items():
    if idx_val == true_label:
        print("  True word:", word)
    if idx_val == pred_label:
        print("  Predicted word:", word)
